# %% [markdown]
# *SQL Basics Assignment

# %% [markdown]
# Q1- Q1. Create a New Database and  Table for Employees
# Task: Create a new database named and Create a table named with the following
# columns:
#
# ans- New Database,
# create database company_db;
# new table,
# create table employees(
# employee_id int,
# first_name varchar(50),
# last_name varchar(50),
# department varchar(50),
# salary int,
# hire_date date
# );
#
# Q2-Insert Data into Employees Table
# Task: Insert the following sample records into the table.
#
# Ans- INSERT INTO employees (employee_id, first_name, last_name, department, salary, hire_date)
# VALUES
# (101, 'Amit', 'Sharma', 'HR', 50000, '2020-01-15'),
# (102, 'Riya', 'Kapoor', 'Sales', 75000, '2019-03-22'),
# (103, 'Raj', 'Mehta', 'IT', 90000, '2018-07-11'),
# (104, 'Neha', 'Verma', 'IT', 85000, '2021-09-01'),
# (105, 'Arjun', 'Singh', 'Finance', 60000, '2022-02-10');
#
# Q3- Display All Employee Records Sorted by Salary (Lowest to Highest)
# Hint: Use the clause on the salary column.
#
# ans-SELECT *
# FROM employees
# ORDER BY salary ASC;
#
# Q4-Show Employees Sorted by Department (A–Z) and Salary (High → Low)
#
# Ans-SELECT *
# FROM employees
# ORDER BY department ASC, salary DESC;
#
# Q5-List All Employees in the IT Department, Ordered by Hire Date (Newest First)
#
# ans- SELECT *
# FROM employees
# WHERE department = 'IT'
# ORDER BY hire_date DESC;
#
# Q6-  Create and Populate a Sales Table
# Task: Create a table to track sales data:
#
# Ans-CREATE TABLE sales(
#   sale_id INT PRIMARY KEY,
#   customer_name VARCHAR(50),
#   product_name VARCHAR(50),
#   amount INT,
#   sale_date DATE
# );
#
# Q7- Display All Sales Records Sorted by Amount (Highest → Lowest)
# Hint: Use ORDER BY amount DESC.
#
# Ans-INSERT INTO sales (sale_id, customer_name, product_name, amount, sale_date)
# VALUES
# (1, 'Aditi', 'Laptop', 70000, '2023-01-10'),
# (2, 'Rahul', 'Mobile', 20000, '2023-02-15'),
# (3, 'Aditi', 'Tablet', 30000, '2023-03-05'),
# (4, 'Sneha', 'Headphones', 5000, '2023-01-25'),
# (5, 'Rahul', 'Monitor', 15000, '2023-04-01');
#
# Q8- Show All Sales Made by Customer “Aditi”
# Hint: Use WHERE customer_name = 'Aditi'.
#
# Ans-SELECT *
# FROM sales
# WHERE customer_name = 'Aditi';
#
#  Q9- What is the Difference Between a Primary Key and a Foreign Key?
#
# Ans-
#
# Q10- What Are Constraints in SQL and Why Are They Used?
#
# Ans-Constraints are rules applied to table columns to ensure data accuracy and integrity.
# ex- PRIMARY KEY, FOREIGN KEY, NOT NULL, UNIQUE etc..
